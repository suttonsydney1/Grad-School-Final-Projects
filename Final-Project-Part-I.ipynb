# %% [markdown]
# # Table of Contents
#  <p>

# %% [markdown]
# # Project Description
#
# In this project, we will explore Chicago Crime Dataset and implement a relational database for storing the data. The key tasks for this project are as follows:
#
# 1. Indentify the features (attributes) in Chicago Crime dataset and design an entity-relationship model
# 2. Refine the model and convert each relation to 3NF (if required)
# 3. Using DDL implement the relations in a postgres server
# 4. Load the given data to the relations
# 5. Execute some interesting queries on the relations
#
#
# ## Dataset
#
# * Dataset URL: **/dsa/data/DSA-7030/Chicago-Crime-Sample-2012.csv**
# * Dataset Description: [pdf](./ChicagoData-Description.pdf)

# %% [markdown]
# ## Dataset exploration

# %%
import pandas as pd
datapath = "/dsa/data/DSA-7030/Chicago-Crime-Sample-2012.csv"
df = pd.read_csv(datapath, index_col=0)

# %%
# check columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334715 entries, 47398 to 2743778
# Data columns (total 22 columns):
# ID                      334715 non-null int64
# Case Number             334715 non-null object
# Date                    334715 non-null object
# Block                   334715 non-null object
# IUCR                    334715 non-null object
# Primary Type            334715 non-null object
# Description             334715 non-null object
# Location Description    334384 non-null object
# Arrest                  334715 non-null bool
# Domestic                334715 non-null bool
# Beat                    334715 non-null int64
# District                334715 non-null int64
# Ward                    334708 non-null float64
# Community Area          334689 non-null float64
# FBI Code                334715 non-null object
# X Coordinate            334132 non-null float64
# Y Coordinate            334132 non-null float64
# Year                    334715 non-null int64
# Updated On              334715 non-null object
# Latitude                334132 non-null float64
# Longitude               334132 non-null float64
# Location                334132 non-null object
# dtypes: bool(2), float64(6), int64(4), object(10)
# memory usage: 54.3+ MB

# %%
df.head()
# Out:
#               ID Case Number           Date                  Block  IUCR  \
# 47398   10433096    HZ170962  1/1/2012 0:00  026XX N MC VICKER AVE  1562
# 47420   10433124    HZ170983  1/1/2012 0:00  026XX N MC VICKER AVE  1544
# 802910  10532867    HZ276514  1/1/2012 0:00     036XX S RHODES AVE  1563
# 803605  10536876    HZ280873  1/1/2012 0:00    062XX S ROCKWELL ST  1153
# 831733   9581929    HX232501  1/1/2012 0:00        006XX W 66TH ST  1563
#
#               Primary Type                          Description  \
# 47398          SEX OFFENSE            AGG CRIMINAL SEXUAL ABUSE
# 47420          SEX OFFENSE       SEXUAL EXPLOITATION OF A CHILD
# 802910         SEX OFFENSE                CRIMINAL SEXUAL ABUSE
# 803605  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 831733         SEX OFFENSE                CRIMINAL SEXUAL ABUSE
#
#        Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 47398             RESIDENCE    True     False  ...  29.0            19.0
# 47420             RESIDENCE    True     False  ...  29.0            19.0
# 802910            APARTMENT   False     False  ...   4.0            35.0
# 803605            RESIDENCE   False     False  ...  15.0            66.0
# 831733            RESIDENCE   False      True  ...   6.0            68.0
#
#         FBI Code  X Coordinate Y Coordinate  Year       Updated On  Latitude  \
# 47398         17           NaN          NaN  2012  5/11/2016 15:48       NaN
# 47420         17           NaN          NaN  2012  5/11/2016 15:48       NaN
# 802910        17           NaN          NaN  2012  5/26/2016 15:51       NaN
# 803605        11           NaN          NaN  2012  5/27/2016 15:48       NaN
# 831733        17           NaN          NaN  2012  8/17/2015 15:03       NaN
#
#        Longitude  Location
# 47398        NaN       NaN
# 47420        NaN       NaN
# 802910       NaN       NaN
# 803605       NaN       NaN
# 831733       NaN       NaN
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#               ID Case Number              Date                 Block  IUCR  \
# 2742387  8951459    HW100757  12/31/2012 23:50    028XX N HALSTED ST   890
# 2741932  8950836    HW100039  12/31/2012 23:55       0000X E OHIO ST  2890
# 2742001  8950918    HW100021  12/31/2012 23:55  035XX W MONTROSE AVE   610
# 2743949  8954299    HW100700  12/31/2012 23:55  058XX S MARYLAND AVE   890
# 2743778  8953937    HW102973  12/31/2012 23:58      037XX N NORA AVE   610
#
#                    Primary Type      Description       Location Description  \
# 2742387                   THEFT    FROM BUILDING                  RESIDENCE
# 2741932  PUBLIC PEACE VIOLATION  OTHER VIOLATION                   SIDEWALK
# 2742001                BURGLARY   FORCIBLE ENTRY                      OTHER
# 2743949                   THEFT    FROM BUILDING  HOSPITAL BUILDING/GROUNDS
# 2743778                BURGLARY   FORCIBLE ENTRY           RESIDENCE-GARAGE
#
#          Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 2742387   False     False  ...  44.0             6.0         6     1170439.0
# 2741932    True     False  ...  42.0             8.0        26     1176775.0
# 2742001   False     False  ...  33.0            16.0         5     1152066.0
# 2743949   False     False  ...   5.0            41.0         6     1182887.0
# 2743778   False     False  ...  36.0            17.0         5     1128745.0
#
#         Y Coordinate  Year     Updated On   Latitude  Longitude  \
# 2742387    1919244.0  2012  2/4/2016 6:33  41.933894 -87.649053
# 2741932    1904213.0  2012  2/4/2016 6:33  41.892508 -87.626224
# 2742001    1929015.0  2012  2/4/2016 6:33  41.961089 -87.716315
# 2743949    1866434.0  2012  2/4/2016 6:33  41.788699 -87.604954
# 2743778    1924002.0  2012  2/4/2016 6:33  41.947762 -87.802171
#
#                               Location
# 2742387  (41.933894393, -87.649052922)
# 2741932  (41.892507592, -87.626223996)
# 2742001  (41.961089289, -87.716314748)
# 2743949  (41.788699253, -87.604954085)
# 2743778  (41.947761848, -87.802170774)
#
# [5 rows x 22 columns]

# %%
df1 = df.groupby('Case Number')['ID'].nunique()
df1.count()
# Out:
# 334715

# %%
df2 = df.groupby('Beat')['Block'].nunique()
df2.head()
# Out:
# Beat
# 111    77
# 112    52
# 113    51
# 114    83
# 121    62
# Name: Block, dtype: int64

# %%
df3 = df.groupby('Location').nunique()
df3
# Out:
#                                ID  Case Number  Date  Block  IUCR  \
# Location
# (36.619446395, -91.686565684)  22           22    22     13    18
# (41.644585429, -87.616512829)   1            1     1      1     1
# (41.644589713, -87.61587983)    1            1     1      1     1
# (41.644606925, -87.608997659)   1            1     1      1     1
# (41.644607723, -87.613055128)   4            4     4      1     2
# ...                            ..          ...   ...    ...   ...
# (42.022536112, -87.674619658)   1            1     1      1     1
# (42.022536147, -87.673670147)   2            2     2      1     2
# (42.022536591, -87.673747428)   1            1     1      1     1
# (42.022548774, -87.675870822)   1            1     1      1     1
# (42.022585817, -87.666121381)   1            1     1      1     1
#
#                                Primary Type  Description  \
# Location
# (36.619446395, -91.686565684)            10           17
# (41.644585429, -87.616512829)             1            1
# (41.644589713, -87.61587983)              1            1
# (41.644606925, -87.608997659)             1            1
# (41.644607723, -87.613055128)             2            2
# ...                                     ...          ...
# (42.022536112, -87.674619658)             1            1
# (42.022536147, -87.673670147)             2            2
# (42.022536591, -87.673747428)             1            1
# (42.022548774, -87.675870822)             1            1
# (42.022585817, -87.666121381)             1            1
#
#                                Location Description  Arrest  Domestic  ...  \
# Location                                                               ...
# (36.619446395, -91.686565684)                    10       2         2  ...
# (41.644585429, -87.616512829)                     1       1         1  ...
# (41.644589713, -87.61587983)                      1       1         1  ...
# (41.644606925, -87.608997659)                     1       1         1  ...
# (41.644607723, -87.613055128)                     2       2         1  ...
# ...                                             ...     ...       ...  ...
# (42.022536112, -87.674619658)                     1       1         1  ...
# (42.022536147, -87.673670147)                     1       1         1  ...
# (42.022536591, -87.673747428)                     1       1         1  ...
# (42.022548774, -87.675870822)                     1       1         1  ...
# (42.022585817, -87.666121381)                     1       1         1  ...
#
#                                Ward  Community Area  FBI Code  X Coordinate  \
# Location
# (36.619446395, -91.686565684)    11               9        11             1
# (41.644585429, -87.616512829)     1               1         1             1
# (41.644589713, -87.61587983)      1               1         1             1
# (41.644606925, -87.608997659)     1               1         1             1
# (41.644607723, -87.613055128)     1               1         2             1
# ...                             ...             ...       ...           ...
# (42.022536112, -87.674619658)     1               1         1             1
# (42.022536147, -87.673670147)     1               1         1             1
# (42.022536591, -87.673747428)     1               1         1             1
# (42.022548774, -87.675870822)     1               1         1             1
# (42.022585817, -87.666121381)     1               1         1             1
#
#                                Y Coordinate  Year  Updated On  Latitude  \
# Location
# (36.619446395, -91.686565684)             1     1           1         1
# (41.644585429, -87.616512829)             1     1           1         1
# (41.644589713, -87.61587983)              1     1           1         1
# (41.644606925, -87.608997659)             1     1           1         1
# (41.644607723, -87.613055128)             1     1           1         1
# ...                                     ...   ...         ...       ...
# (42.022536112, -87.674619658)             1     1           1         1
# (42.022536147, -87.673670147)             1     1           1         1
# (42.022536591, -87.673747428)             1     1           1         1
# (42.022548774, -87.675870822)             1     1           1         1
# (42.022585817, -87.666121381)             1     1           1         1
#
#                                Longitude  Location
# Location
# (36.619446395, -91.686565684)          1         1
# (41.644585429, -87.616512829)          1         1
# (41.644589713, -87.61587983)           1         1
# (41.644606925, -87.608997659)          1         1
# (41.644607723, -87.613055128)          1         1
# ...                                  ...       ...
# (42.022536112, -87.674619658)          1         1
# (42.022536147, -87.673670147)          1         1
# (42.022536591, -87.673747428)          1         1
# (42.022548774, -87.675870822)          1         1
# (42.022585817, -87.666121381)          1         1
#
# [162285 rows x 22 columns]

# %% [markdown]
# ## 1.1 Design an Entity Relationship Model for the Chicago Crime Dataset
#
# * List all the entities with associated attributes
# * Indentify primary and foreign keys

# %% [raw]
# 1. Case Record
#     ID, PK
#     Case Number
#     Updated on
#
# 2. Location Description
#     ID, PK
#     Latitude
#     Longitude
#     Location Description
#
# 3. Block
#    Latitude PK, FK
#    Longitude PK, FK
#    Block
#
# 4. Beat
#    Latitude PK, FK
#    Longitude PK, FK
#    Beat
#
# 5. District
#    Beat PK, FK
#    District
#
# 6. Date of Occurance
#    ID PK,FK
#    Year
#    Date
#
# 7. Case Details
#    ID PK,FK
#    IUCR
#    FBI
#    Arrest
#    Domestic
#
# 8. IUCR
#    IUCR PK, FK
#    FBI PK, FK
#    Primary Type
#    Description
#
# 9. Area Description
#    lat PK, FK
#    long PK, FK
#    Ward
#    Community Area

# %% [markdown]
# ## 1.2 If required, refine your initial set of relations and convert each of the relations to 3NF
#
# While converting a relation to 3NF, please write down the process in the following cell.

# %% [raw]
# This has been converted to 3NF.
#
# Assumptions made here:
# - Multiple beats per district but a single beat can identify a unique district
# - IUCR and FBI number can uniquely determine primary type
# - A block can only be uniquely determined by lat and long. Blocks can be part of multiple beats, districts, etc.
# - Ward, community area, district are all independant of one another. Can be identified only by the lat/long
#
# No other items are transitively dependent.

# %% [markdown]
# ## 1.3 Final ERD
#
# * Draw an entitiy relationship diagram once you are done with 1.1 and 1.2
# * Use crow's foot notation to specify the cardinality
# * Show the primary and foreign keys in the diagram

# %% [markdown]
# Please upload your ERD to the Module 8 exercises folder. Link the file [image](IMG_1452.jpg). Once you are done, change this cell type to Markdown and execute. ![image](IMG_1452.jpg)

# %% [markdown]
# ## <center> Part-I ends here</center>

# %% [markdown]
# To access Part II, use this link: [Final Project Part II](./Final-Project-Part-II.ipynb)
